# %%
import pandas as pd
import numpy as np
import onnxruntime as rt
import onnx
from skl2onnx import convert_sklearn, to_onnx, update_registered_converter
from skl2onnx.common.data_types import FloatTensorType
from skl2onnx import to_onnx
from sklearn.model_selection import RepeatedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
from xgboost import XGBClassifier
import xgboost as xgb
from tqdm.notebook import tqdm
from sklearn.metrics import roc_auc_score, roc_curve
from skl2onnx.common.shape_calculator import (
    calculate_linear_classifier_output_shapes,
)
from onnxmltools.convert.xgboost.operator_converters.XGBoost import convert_xgboost

# %%
data = pd.read_csv("data/train_augmented.csv")
test_data= pd.read_csv("data/test_en.csv")


X_train, y_train = data.drop(['checked'], axis=1), data['checked']
X_test, y_test = test_data.drop(['checked'], axis=1), test_data['checked']

cv    = RepeatedKFold(n_splits=5, n_repeats=10, random_state=101)
folds = [(train,test) for train, test in cv.split(X_train, y_train)]

# %%
metrics = ['auc', 'fpr', 'tpr', 'thresholds', 'importance']
results = {
    'train': {m:[] for m in metrics},
    'val'  : {m:[] for m in metrics},
    'test' : {m:[] for m in metrics}
}

# %%
params = {
    'objective'   : 'binary:logistic',
    'eval_metric' : 'logloss'
}

# %%
importances = []
dtest = xgb.DMatrix(X_test, label=y_test)
for train, test in tqdm(folds, total=len(folds)):
    dtrain = xgb.DMatrix(X_train.iloc[train,:], label=y_train.iloc[train])
    dval   = xgb.DMatrix(X_train.iloc[test,:], label=y_train.iloc[test])
    model  = xgb.train(
        dtrain                = dtrain,
        params                = params, 
        evals                 = [(dtrain, 'train'), (dval, 'val')],
        num_boost_round       = 1000,
        verbose_eval          = False,
        early_stopping_rounds = 10,
    )
    importances.append(model.get_score())
    sets = [dtrain, dval, dtest]
    for i,ds in enumerate(results.keys()):
        y_preds              = model.predict(sets[i])
        labels               = sets[i].get_label()
        fpr, tpr, thresholds = roc_curve(labels, y_preds)
        results[ds]['fpr'].append(fpr)
        results[ds]['tpr'].append(tpr)
        results[ds]['thresholds'].append(thresholds)
        results[ds]['auc'].append(roc_auc_score(labels, y_preds))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
importances_agg = dict()
for importance_dict in importances:
    for key in importance_dict:
        if key not in importances_agg:
            importances_agg[key] = {"count": 1, "sum": importance_dict[key]}
        else:
            importances_agg[key]["sum"] += importance_dict[key]
            importances_agg[key]["count"] += 1

avg_importance = []

for key in importances_agg:
    imp_sum = importances_agg[key]["sum"]
    imp_count = importances_agg[key]["count"]
    imp_avg = imp_sum / imp_count
    importances_agg[key]["avg"] = imp_avg
    avg_importance.append((imp_avg, key))
avg_importance.sort(reverse=True)

# %%
print(avg_importance)
# Out:
# [(132.9, 'person_age_during_investigation'), (84.52, 'exemption_day_history_because_of_your_medical_conditions'), (73.9, 'personal_qualities_days_since_language_requirement'), (70.76, 'personal_qualities_days_since_last_updated'), (69.88, 'obstacle_days_physical_problems'), (67.04, 'obstacles_days_financial_problems'), (57.68, 'contact_subject_no_show'), (52.06, 'address_days_at_address'), (51.2, 'exemption_days_history_mean'), (49.68, 'relationship_child_age_difference_parent_first_child'), (49.42, 'appointment_number_of_words'), (49.34, 'relationship_partner_total_days_partner'), (48.52, 'contact_type_last_year_outgoing_documents'), (48.32, 'obstacle_days_psychological_problems'), (41.46, 'contacts_type_of_document_outgoing'), (38.6, 'typering_days_sum'), (36.64, 'relationship_other_current_costsharer'), (35.78, 'appointment_last_year_number_of_words'), (33.44, 'instrument_ladder_reason_termination_reason_sucuessful'), (33.2, 'instrument_ladder_history_activation'), (30.24, 'availability_amount_history_abnormal_due_to_medical_conditions'), (28.98, 'relationship_child_current_number'), (27.76, 'pla_history_development'), (27.6, 'relationship_other_costsharer'), (27.24, 'relationship_other_history_type_cost_sharer'), (26.36, 'appointment_signal_for_employee'), (26.18, 'contacts_type_document_incoming'), (24.68, 'contacts_type_e_-mail_incoming'), (24.68, 'contacts_type_different'), (23.54, 'participation_act_reintegration_ladder_work_re_integration'), (22.02, 'contacts_subject_finance_situation'), (22.0, 'contacts_type_of_phone_call_incoming'), (21.94, 'contacts_different_kids_of_contact_last_year'), (21.86, 'contact_subject_income'), (21.8, 'appointment_result_filled_in_unique'), (21.72, 'pla_result_other_than_follow_education_regular_work_or_as_a_self_-employed_person'), (21.26, 'instrument_ladder_current_activation'), (20.3, 'address_number_of_shipping_address'), (19.76, 'contacts_type_last_year_e_-mail_outgoing'), (19.62, 'contacts_subject_other'), (18.98, 'contacts_subject_process'), (18.96, 'contacts_subject_document_type_agreement'), (17.76, 'pla_signed_in_history'), (17.42, 'contacts_subject_matching'), (17.34, 'appointment_effort_period'), (17.24, 'exemption_reason_history_temporary_exemption_work_and_obligation'), (17.2, 'personal_qualities_language_requirement_satisfied'), (17.0, 'pla_hist_pla_category_objective_16'), (16.72, 'relationship_other_history_form_other_resident'), (16.24, 'address_number_of_brp_addresses'), (16.1, 'relationship_child_young_adult'), (16.06, 'skill_applying_profesional_expertise'), (15.96, 'appointment_last_year_result_filled_in_unique'), (15.9, 'personal_qualities_spoken_language'), (15.44, 'contacts_type_e_-mail_outgoing'), (14.42, 'relationship_other_current_form_other'), (14.2, 'contacts_topic_documents'), (13.48, 'contacts_type_of_phone_call_outgoing'), (13.42, 'contacts_subject_sick_or_cancellation'), (13.38, 'contacts_subject_recovery_request'), (13.36, 'appointment_last_year_result_filled_in'), (13.3, 'personal_characteristics_caseworker_estimate_of_time_before_reintegration'), (13.08, 'contacts_topic_assessment_language_requirement'), (12.46, 'contacts_subject_contact_third_parties'), (12.32, 'contacts_type_last_year_e_-mail_incoming'), (11.86, 'contacts_subject_document_type_cv'), (11.76, "personal_characteristics_client's_estimate_of_time_before_reintegration"), (11.68, 'contacts_subject_work_motivation'), (11.66, 'address_number_of_different_neighborhoods'), (11.64, 'participation_act_reintegration_ladder_supporting_instruments'), (11.44, 'appointment_progress_interview'), (11.16, 'contacts_type_conversation_on_location'), (11.04, 'contacts_type_report_participation'), (11.0, 'contacts_subject_income'), (10.88, 'contacts_subject_care'), (10.82, 'contacts_type_last_year_interview'), (10.64, 'contacts_type_rib_report'), (10.46, 'participation_act_current_projects_unique'), (10.36, 'pla_end_of_objective_reaches_new_trajectory_plan'), (9.94, 'appointment_last_year_progress_registrat ...

# %%
model = xgb.XGBClassifier(max_depth=25, n_estimators = 200)

pipeline = Pipeline([
    ('standard_scaler', StandardScaler()), 
    # ('selector', VarianceThreshold),
    # ('pca', PCA()), 
    ('model', model)
])

# param_grid = {
#     # 'pca__n_components': [50, 100, 150],
#     'model__max_depth': [20, 25, 30],
#     'model__n_estimators': [175, 200]
# }

# grid = HalvingGridSearchCV(pipeline, param_grid, cv=5, n_jobs=-1, scoring='roc_auc', verbose=10)

# %%
# grid.fit(X_train, y_train)
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('model',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=None, device=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric=None,
#                                feature_types=None, gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=None, n_jobs=None,
#                                num_parallel_tree=None, random_state=None, ...))])

# %%
# print(grid.best_params_)
# Out:
# {'model__max_depth': 25, 'model__n_estimators': 200}

# %%
y_pred = pipeline.predict(X_test)
original_accuracy = accuracy_score(y_test, y_pred)
print('Accuracy of the original model: ', original_accuracy)
# Out:
# Accuracy of the original model:  0.9437065148640101

# %%
update_registered_converter(
    XGBClassifier,
    "XGBoostXGBClassifier",
    calculate_linear_classifier_output_shapes,
    convert_xgboost,
    options={"nocl": [True, False], "zipmap": [True, False, "columns"]},
)

# %%
booster = model.get_booster()
original_feature_names = booster.feature_names
if original_feature_names is not None:
    onnx_converter_conform_feature_names = [f"f{num}" for num in range(len(original_feature_names))]
    booster.feature_names = onnx_converter_conform_feature_names

# %%
onnx_model = convert_sklearn(
    pipeline, initial_types=[('X', FloatTensorType((None, X_train.shape[1])))],
    target_opset=12)

# %%
sess = rt.InferenceSession(onnx_model.SerializeToString())
y_pred_onnx =  sess.run(None, {'X': X_test.values.astype(np.float32)})

accuracy_onnx_model = accuracy_score(y_test, y_pred_onnx[0])
print('Accuracy of the ONNX model: ', accuracy_onnx_model)
# Out:
# Accuracy of the ONNX model:  0.9437065148640101

# %%
onnx.save(onnx_model, "model/model2.onnx")
